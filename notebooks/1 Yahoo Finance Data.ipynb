# %% [markdown]
# # Download Yahoo Data

# %% [markdown]
# ## Setup

# %%
# %load_ext nb_black

# %%
# Import libraries
import pandas as pd
from investing.tools.functions import price
from investing.config.file_paths import input_data, output_data
from forex_python.converter import CurrencyRates

# %% [markdown]
# ## Configure

# %%
# File names
input_file = "company_names.csv"
output_file = "prices.csv"

# %% [markdown]
# ## Load Data

# %%
# Open the file
df_companies = pd.read_csv(input_data / input_file)

# %%
# Display data
df_companies
# Out:
#        ticker                                       name       type currency
# 0       AAL.L                              AngloAmerican   Dividend      GBP
# 1        AAPL                                      Apple   CashFlow      USD
# 2         ACN                                  Accenture   CashFlow      USD
# 3      ALA.TO                                    AltaGas   Dividend      CAD
# 4        AMZN                                 Amazon.com   CashFlow      USD
# 5         AQN                                  Algonquin   Dividend      USD
# 6          AY                                  Atlantica   Dividend      USD
# 7        BABA                                    Alibaba   CashFlow      USD
# 8        BEPC                       Brookfield Renewable   Dividend      USD
# 9        BIPC                  Brookfield Infrastructure   Dividend      USD
# 10         BK        Bank of New York Mellon Corporation   Dividend      USD
# 11        BLK                                  BlackRock   Dividend      USD
# 12        BMO                           Bank of Montreal   Dividend      USD
# 13        BNS                        Bank of Nova Scotia   Dividend      USD
# 14       BP.L                                         BP   Dividend      GBP
# 15      BRK-B                         Berkshire Hathaway  Insurance      USD
# 16  BTB-UN.TO                                   BTB REIT   Dividend      CAD
# 17       COST                                     Costco   CashFlow      USD
# 18        CVX                                    Chevron   Dividend      USD
# 19        DFS                Discover Financial Services   CashFlow      USD
# 20       EBAY                                       eBay   CashFlow      USD
# 21        ENB                                   Enbridge   Dividend      USD
# 22        FTS                                     Fortis   Dividend      USD
# 23     GLEN.L                                   Glencore   Dividend      GBP
# 24       GMRE                        Global Medical REIT   Dividend      USD
# 25       GOOG                                   Alphabet   CashFlow      USD
# 26      IAG.L  International Consolidated Airlines Group   CashFlow      GBP
# 27        JPM                                   JPMorgan   Dividend      USD
# 28         MA                                 Mastercard   CashFlow      USD
# 29       MELI                               MercadoLibre   CashFlow      USD
# 30        MFC                                   Manulife  Insurance      USD
# 31        MKL                                     Markel  Insurance      USD
# 32       MSFT                                  Microsoft   CashFlow      USD
# 33     NFI.TO                                  NFI Group   CashFlow      CAD
# 34       NXPI                         NXP Semiconductors   CashFlow      USD
# 35       PYPL                                     PayPal   CashFlow      USD
# 36        RIO                                  Rio Tinto   Dividend      USD
# 37        SAP                                     Saputo   CashFlow      USD
# 38       SHEL                                      Shell   Dividend      USD
# 39        SLF                                    SunLife  Insurance      USD
# 40          T                                       AT&T   Dividend      USD
# 41        TDG                                  TransDigm   CashFlow      USD
# 42        TRP                                  TC Energy   Dividend      USD
# 43         TU                                      TELUS   Dividend      USD
# 44          V                                       Visa   CashFlow      USD
# 45        XOM                                Exxon Mobil   Dividend      USD

# %% [markdown]
# ## Extract and Convert Prices

# %%
df_companies["price"] = df_companies["ticker"].apply(price)

# %%
df_companies
# Out:
#        ticker                                       name       type currency  \
# 0       AAL.L                              AngloAmerican   Dividend      GBP
# 1        AAPL                                      Apple   CashFlow      USD
# 2         ACN                                  Accenture   CashFlow      USD
# 3      ALA.TO                                    AltaGas   Dividend      CAD
# 4        AMZN                                 Amazon.com   CashFlow      USD
# 5         AQN                                  Algonquin   Dividend      USD
# 6          AY                                  Atlantica   Dividend      USD
# 7        BABA                                    Alibaba   CashFlow      USD
# 8        BEPC                       Brookfield Renewable   Dividend      USD
# 9        BIPC                  Brookfield Infrastructure   Dividend      USD
# 10         BK        Bank of New York Mellon Corporation   Dividend      USD
# 11        BLK                                  BlackRock   Dividend      USD
# 12        BMO                           Bank of Montreal   Dividend      USD
# 13        BNS                        Bank of Nova Scotia   Dividend      USD
# 14       BP.L                                         BP   Dividend      GBP
# 15      BRK-B                         Berkshire Hathaway  Insurance      USD
# 16  BTB-UN.TO                                   BTB REIT   Dividend      CAD
# 17       COST                                     Costco   CashFlow      USD
# 18        CVX                                    Chevron   Dividend      USD
# 19        DFS                Discover Financial Services   CashFlow      USD
# 20       EBAY                                       eBay   CashFlow      USD
# 21        ENB                                   Enbridge   Dividend      USD
# 22        FTS                                     Fortis   Dividend      USD
# 23     GLEN.L                                   Glencore   Dividend      GBP
# 24       GMRE                        Global Medical REIT   Dividend      USD
# 25       GOOG                                   Alphabet   CashFlow      USD
# 26      IAG.L  International Consolidated Airlines Group   CashFlow      GBP
# 27        JPM                                   JPMorgan   Dividend      USD
# 28         MA                                 Mastercard   CashFlow      USD
# 29       MELI                               MercadoLibre   CashFlow      USD
# 30        MFC                                   Manulife  Insurance      USD
# 31        MKL                                     Markel  Insurance      USD
# 32       MSFT                                  Microsoft   CashFlow      USD
# 33     NFI.TO                                  NFI Group   CashFlow      CAD
# 34       NXPI                         NXP Semiconductors   CashFlow      USD
# 35       PYPL                                     PayPal   CashFlow      USD
# 36        RIO                                  Rio Tinto   Dividend      USD
# 37        SAP                                     Saputo   CashFlow      USD
# 38       SHEL                                      Shell   Dividend      USD
# 39        SLF                                    SunLife  Insurance      USD
# 40          T                                       AT&T   Dividend      USD
# 41        TDG                                  TransDigm   CashFlow      USD
# 42        TRP                                  TC Energy   Dividend      USD
# 43         TU                                      TELUS   Dividend      USD
# 44          V                                       Visa   CashFlow      USD
# 45        XOM                                Exxon Mobil   Dividend      USD
#
#           price
# 0   4055.000000
# 1    166.559998
# 2    318.329987
# 3     28.309999
# 4   3041.050049
# 5     14.590000
# 6     35.080002
# 7    105.419998
# 8     37.549999
# 9     71.269997
# 10    52.139999
# 11   738.039978
# 12   116.889999
# 13    73.800003
# 14   382.850006
# 15   323.640015
# 16     4.080000
# 17   528.000000
# 18   154.139999
# 19   116.120003
# 20    55.090000
# 21    44.400002
# 22    46.349998
# 23   476.779999
# 24    15.650000
# 25  2695.030029
# 26   138.461395
# 27   139.279999
# 28   344.089996
# 29  1140.900024
# 30    20.010000
# 31  1258.209961
# 32   300.190002
# 33    18.490000
# 34   188.350006
# 35   106.610001
# 36    83.540001
# 37   113.190002
# 38    54.619999
# 39    52.150002
# 40    23.820000
# 41   675.510010
# 42    55.029999
# 43    25.670000
# 44   208.479996
# 45    80.529999

# %%
# Set currency conversions for non-USD
c = CurrencyRates()
gbp_usd = c.convert('GBP', 'USD', 1)
cad_usd = c.convert('CAD', 'USD', 1)

# %%
# Convert GBP currencies
mask = df_companies['currency'] == 'GBP'
df_companies.loc[mask, 'price'] /= 100
df_companies.loc[mask, 'price'] = df_companies.loc[mask, 'price'] * gbp_usd

# Convert CAD currencies
mask = df_companies['currency'] == 'CAD'
df_companies.loc[mask, 'price'] = df_companies.loc[mask, 'price'] * cad_usd

# %% [markdown]
# ## Save

# %%
# Write back df to csv
df_companies.to_csv(output_data / output_file, index=False)
